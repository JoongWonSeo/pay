# %%
import dotenv


dotenv.load_dotenv(override=True)
# Out:
# True

# %%
from pay.tiktok import TiktokService


s = TiktokService()

await s.start()

# %%
await s.get_user_info("tenminai.korean")
# Out:
# TiktokChannel(id='7532962856628225046', nickname='Tenmin AI Korean', handle='tenminai.korean', description='Your AI Korean 🇰🇷 tutor for speaking\n\nSearch "Tenmin AI" on your App Store', avatar_url='https://p16-common-sign.tiktokcdn-us.com/tos-maliva-avt-0068/f611aa99e7db2b1f81ce145c7b063078~tplv-tiktokx-cropcenter:1080:1080.jpeg?dr=9640&refresh_token=7eec0643&x-expires=1763416800&x-signature=k%2BapBsXqz6MPT1rARlqzCbzcdjQ%3D&t=4d5b0474&ps=13740610&shp=a5d48078&shcp=81f88b70&idc=useast8', stats=TiktokUserStats(follower_count=1122, following_count=1, heart_count=21700, video_count=7))

# %%
# await s.get_user_info("violesdcwev")

# %%
videos = []
async for v in s.get_user_videos("violesdcwev"):
    videos.append(v)
    print(v)
# Out:
# id='7536560005613423894' date_posted=datetime.datetime(2025, 8, 9, 5, 22, 3) description='#learningchinese #learninglanguages #learningchineselanguage #mandarin #chineselanguage #chinese  #languagelearning #language #mandarinchinese #studytok #hanyu #studytips' url=None dynamic_cover_url='https://p16-common-sign.tiktokcdn-us.com/tos-no1a-i-photomode-no/58e29a8a0cd34a64b71790798d754dc7~tplv-photomode-image.jpeg?dr=9616&x-expires=1763416800&x-signature=Yn1IDPtOKP4YjGw36q9C0r8d4%2BQ%3D&t=4d5b0474&ps=13740610&shp=81f88b70&shcp=9b759fb9&idc=useast8&ftpl=1' stats=TiktokPostStats(play_count=732700, like_count=99200, comment_count=451, share_count=4196, save_count=44300)
# ...

# %%
await s.end()

# %%
from datetime import datetime


datetime.fromtimestamp(1762854097)
# Out:
# datetime.datetime(2025, 11, 11, 1, 41, 37)
